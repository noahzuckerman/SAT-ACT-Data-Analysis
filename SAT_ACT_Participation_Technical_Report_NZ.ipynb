# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Executive Summary
#
# ### Overview
#
# The ACT has been outpacing the SAT in participation in recent years, steadily gaining ground across the country. The College Board implemented some major design changes to the SAT in 2016, in an attempt to revitalize their test. We've been asked by the College Board to review the last three years of SAT and ACT data to identify strategies to improve the SAT participation in future years.
#
# ### Problem Statement
#
# This technical report reviews aggregate SAT and ACT scores and participation rates from each state in the United States in 2017,2018 and 2019 to see if we can generate any strategies the College Board might employ to increase SAT participation moving forward.
#
# Throughout the report we'll seek to identify trends in the data and combine the data analysis with outside research to identify likely factors influencing participation rates and scores in various states. The result of this data analysis culminates in targetted strategic reccommendations which have been presented to the executives of the College Board with the intent of improving statewide participation in Ohio.

# %% [markdown]
# ### Contents:
# - [2017 Data Import & Cleaning](#2017-Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [2019 Data Import and Cleaning](#2019-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Additional Visualizations](#Additional-Visualizations)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)
# - [Decriptive and Inferential Statistics](#Bonus:-Descriptive-and-Inferential-Statistics)

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |Id|int64|train,test|Unique record identifier|
# |PID|int64|train,test|Alternative unique record identifier|
# |MS SubClass|int64|train,test|The building class (e.g. Duplex, 1-Story 1946 & Newer All Styles etc.)|
# |MS Zoning|object|train,test|Identifies the general zoning classification of the sale (e.g. A - Agirculture, C - Commercial, etc)|
# |Lot Frontage|float64|train,test|Linear feet of street connected to property|
# |Lot Area|int64|train,test|Lot size in square feet|
# |Street|object|train,test|Type of road access to property (Gravel or Paved)|
# |Alley|object|train,test|Type of alley access to property|
# |Lot Shape|object|train,test|General shape of property|
# |Land Contour|object|train,test|Flatness of the property|
# |Utilities|object|train,test|Type of utilities available|
# |Lot Config|object|train,test|Lot configuration|
# |Land Slope|object|train,test|Flatness of the property|
# |Neighborhood|object|train,test|Physical locations within Ames city limits|
# |Condition 1|object|train,test|Proximity to main road or railroad|
# |Condition 2|object|train,test|Proximity to main road or railroad (if second is present)|
# |Bldg Type|object|train,test|Type of dwelling|
# |House Style|object|train,test|Style of dwelling
# |Overall Qual|int64|train,test|Overall material and finish quality|
# |Overall Cond|int64|train,test|Overall condition rating|
# |Year Built|int64|train,test|Original construction date|
# |Year Remod/Add|int64|train,test|Remodel date (same as construction date if no remodeling or additions)|
# |Roof Style|object|train,test|Type of roof|
# |Roof Matl|object|train,test|Roof material|
# |Exterior 1st|object|train,test|Exterior covering on house|
# |Exterior 2nd|object|train,test|Exterior covering on house (if more than one material)|
# |Mas Vnr Type|object|train,test|Masonry veneer type|
# |Mas Vnr Area|float64|train,test|Masonry veneer area in square feet|
# |Exter Qual|object|train,test|Exterior material quality|
# |Exter Cond|object|train,test|Present condition of the material on the exterior|
# |Foundation|object|train,test|Type of foundation|
# |Bsmt Qual|object|train,test|Height of the basement|
# |Bsmt Cond|object|train,test|General condition of the basement|
# |Bsmt Exposure|object|train,test|Walkout or garden level basement walls|
# |BsmtFin Type 1|object|train,test|Quality of basement finished area|
# |BsmtFin SF 1|int64|train,test|Type 1 finished square feet|
# |BsmtFin Type 2|object|train,test|Quality of second finished area (if present)|
# |BsmtFin SF 2|int64|train,test|Type 2 finished square feet|
# |Bsmt Unf SF|int64|train,test|Unfinished square feet of basement area|
# |Total Bsmt SF|int64|train,test|Total square feet of basement area|
# |Heating|object|train,test|Type of heating|
# |Heating QC|object|train,test|Heating quality and condition|
# |Central Air|object|train,test|Central air conditions (Y/N)|
# |Electrical|object|train,test|Electrical system|
# |1st Flr SF|int64|train,test|First floor square feet|
# |2nd Flr SF|int64|train,test|Second floor square feet|
# |Low Qual Fin SF|int64|train,test|Low quality finished square feet (all floors)|
# |Gr Liv Area|int64|train,test|Above grade(ground) living area square feet|
# |Bsmt Full Bath|int64|train,test|Basement full bathrooms|
# |Bsmt Half Bath|int64|train,test|Basement half bathrooms|
# |Full Bath|int64|train,test|Full bathrooms above grade|
# |Half Bath|int64|train,test|Half baths above grade|
# |Bedroom AbvGr|int64|train,test|Number of bedrooms above basement level|
# |Kitchen AbvGr|int64|train,test|Number of kitchens|
# |Kitchen Qual|object|train,test|Kitchen quality|
# |TotRms AbvGrd|int64|train,test|Total rooms above grade (does not include bathrooms)|
# |Functional|object|train,test|Home functionality rating|
# |Fireplaces|int64|train,test|Number of fireplaces|
# |Fireplace Qu|object|train,test|Fireplace quality|
# |Garage Type|object|train,test|Garage Location|
# |Garage Yr Blt|float64|train,test|Year garage was built|
# |Garage Finish|object|train,test|Interior finish of the garage|
# |Garage Cars|int64|train,test|Size of garage in car capacity|
# |Garage Area|int64|train,test|Size of garage in square feet|
# |Garage Qual|object|train,test|Garage quality|
# |Garage Cond|object|train,test|Garage condition|
# |Paved Drive|object|train,test|Paved driveway|
# |Wood Deck SF|int64|train,test|Wood deck area in square feet|
# |Open Porch SF|int64|train,test|Open porch area in square feet|
# |Enclosed Porch|int64|train,test|Enclosed porch area in square feet|
# |3Ssn Porch|int64|train,test|Three season porch area in square feet|
# |Screen Porch|int64|train,test|Screen porch area in square feet|
# |Pool Area|int64|train,test|Pool area in square feet|
# |Pool QC|object|train,test|Pool quality|
# |Fence|object|train,test|Fence quality|
# |Misc Feature|object|train,test|Miscellaneous feature not coveed in other categories (Elevator, Shed, etc)|
# |Misc Val|int64|train,test|$ Value of miscellaneous feature|
# |Mo Sold|int64|train,test|Month sold|
# |Yr Sold|int64|train,test|Year sold|
# |Sale Type|object|train,test|Type of sale|
# |SalePrice|int64|test|Price of sale|

# %% [markdown]
# ### Dataset Overview
#
# #### Data Dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT 17/18/19|The U.S. state where the test results were aggregated from|
# |part_sat_*year*|float|SAT 17/18/19|The participation rate of students who took the test out of the whole student population|
# |ebrw_sat_*year*|integer|SAT 17/18/19|The total score in the evidence-based reading and writing sub test section|
# |math_sat_*year*|integer|SAT 17/18/19|The total score in the math sub test section|
# |total_sat_*year*|integer|SAT 17/18/19|The total aggregate score of the test (sum total of the math and ebrw section)|
# |state|object|ACT 17/18/19|The U.S. state where the test results were aggregated from|
# |part_act_*year*|float|ACT 17/18/19|The participation rate of students who took the test out of the whole student population|
# |english_act_2017|float|ACT 17|The total score in the english sub test section|
# |math_act_*year*|float|ACT 17|The total score in the math sub test section|
# |reading_act_*year*|float|ACT 17|The total score in the reading sub test section|
# |science_act_*year*|float|ACT 17|The total score in the science sub test section|
# |composite_act_*year*|float|ACT 17/18/19|The total aggregate score of the test (average of the english, math, reading and science sections)|
#
# #### Provided Data
#
# For this project, I've used the following six datasets as source data:
#
# - [2017 SAT Scores](./data/sat_2017.csv)
# - [2017 ACT Scores](./data/act_2017.csv)
# - [2018 SAT Scores](./data/sat_2018.csv)
# - [2018 ACT Scores](./data/act_2018.csv)
# - [2019 SAT Scores](./data/sat_2019.csv)
# - [2019 ACT Scores](./data/act_2019.csv)
#
# You can see the sources for the SAT data [here](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/) and [here](https://blog.prepscholar.com/average-sat-scores-by-state-most-recent), and the source for the ACT data [here](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows). The data source referenced in order to correct the data entry errors discovered in the data clesning phase can be found [here](https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf).
#
# Additionally, I've created the following four datasets for the purpose of analysis.
#
# - [2017 Combined Data](./data/combined_2017.csv)
# - [2018 Combined Data](./data/combined_2018.csv)
# - [2019 Combined Data](./data/combined_2019.csv)
# - [Final Combined Data](./data/final.csv)
#
# The Final dataset is the most relevant dataset to reference for this analysis. It includes cleansed data from both tests in all three years.
#
# This data is compiled into CSV files which are included in the data directory of this repo.

# %% [markdown]
# #### Primary Findings & Insights
#
# The ACT and SAT participation distributions roughly mirror each other, with states geographically tending to prefer one test or the other.
#
# There are strong regional and histroical affiliations associated with test preference in each state. Coastal states tend to favor the SAT, while Midwestern and Mountain states tend to favor the ACT.
#
# ACT and SAT scores are inversely correlated with their respective participation rates. This is most likely due to selection bias.
#
# #### Recommendations
#
# We can apply the successful learnings from Colorado's successful SAT transition and leverage the overhauled student-accessible SAT design to gain traction amonst Ohio school districts for their future decision making. Ohio has a large amount of potential to improve SAT participation rates (<80%) and has already displayed the propensity to improve participation rates signifcantly in a short time frame (25% in 1 year).
#
# #### Next Steps
#
# Moving onto the next phase of this analysis would require additional resources and data. In order to properly strategize our campaign in Ohio, it will be critical to get access to more granular statewide data by school district in order to better understand local trends and ensure our approach aligns to their requirements & needs.

# %%
#Import modules with aliases:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Import data for 2017:
sat_2017 = pd.read_csv('data/sat_2017.csv')
act_2017 = pd.read_csv('data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Display first 10 rows of sat_2017
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
#Display first 10 rows of act_2017
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# SAT Data:
# - The SAT data describes the aggregate average participation rates, EBRW score, Math score and Total score by State
# - The SAT data contains 5 column dimensions and 51 rows
# - The State and Participation columns are objects or string types
# - The EBRW, Math and Total columns are integer data types
# - The Total column is calculated by summing the EBRW and Math columns
#
# ACT Data:
# - The ACT data describes the aggregate average participation rates, English score, Math score, Reading score, Science score and Composite score by State
# - The SAT data contains 7 column dimensions and 52 rows (includes the National averages)
# - The State, Participation and Composite columns are objects or string types
# - The English, Math, Reading and Science columns are float data types
# - The Composite column is calculated by averaging the scored in the English, Math, Reading and Science columns

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
#Check the 2017 datasets for null values
sat_2017.info()
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
# ...

# %% [markdown]
# #### 4a Answer:
# Yes the data looks complete as there are no null/NaN values in any columns

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
#Checking the descriptive statistics for sat_2017
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
# Out of the min and max values for each test/subtest of SAT data, the only discrepancy in the data is the min of 
# 52.00 for the math subtest. The Math value for Maryland should be 524 according to the source data:

sat_2017.sort_values('Math').head(5)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 20              Maryland           69%                                 536
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
#
#     Math  Total
# 20    52   1060
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005

# %%
#Checking the descriptive statistics for act_2017
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
# Out of the min and max values for each test/subtest of ACT data, the only discrepancy in the data is the min of 
# 2.3 for the math subtest. The Math value for Maryland should be 23.2 according to the source data:

act_2017.sort_values('Science').head()
# Out:
#              State Participation  English  Math  Reading  Science Composite
# 21        Maryland           28%     23.3  23.1     24.2      2.3      23.6
# 29          Nevada          100%     16.3  18.0     18.1     18.2      17.8
# 25     Mississippi          100%     18.2  18.1     18.8     18.8      18.6
# 41  South Carolina          100%     17.5  18.6     19.1     18.9      18.7
# 34  North Carolina          100%     17.8  19.3     19.6     19.3      19.1

# %% [markdown]
# #### Answer:
#
# SAT:
# - Out of the min and max values for each test/subtest, the only discrepancy in the data is the min score of 52 for the math subtest. This was likley caused due to human error during data gathering.
# - The Math subtest score for Maryland should be 524 as seen in the source data here:
# [SAT 2017 Source Data](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
#
# ACT:
# - Out of the min and max values for each test/subtest, the only discrepancy in the data is the min score of 2.3 for the Science subtest. This was likley caused due to human error during data gathering.
# - The Math subtest score for Maryland should be 23.2 as seen in the source data here:
# [ACT 2017 Source Data](https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf)**
#
# **Note the source data link originally provided in this notebook does not give the 2017 by state data required to populate this missing data. So the link shared here was found online published by act.inc

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#Fixing the mayrland subtest value errors in the 2017 SAT dataset
sat_2017.loc[sat_2017['State'] == 'Maryland','Math'] = 524

# %%
#Fixing the mayrland subtest value errors in the 2017 ACT dataset
act_2017.loc[act_2017['State'] == 'Maryland','Science'] = 23.2

# %%
#Checking implementation of new values
print("SAT:",sat_2017['Math'][20]," ACT:",act_2017['Science'][21])
# Out:
# SAT: 524  ACT: 23.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#Printing the dtypes for each featureacross both sat_2017 and act_2017 data
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
#Confirm the state dtype is inf fact a string
type(sat_2017['State'][0])
# Out:
# str

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
#Confirm the state dtype is inf fact a string
type(act_2017['State'][0])
# Out:
# str

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# #### Answer:
#
# - The SAT participation column datatype is a string but should be a converted to a float
# - Both the ACT participation and composite column datatypes are strings but should be converted to floats

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#Defining function to re-type incorrectly typed data from a string to a float

def str_to_float(x):
    if '%' in x:
        try:
            x = x.replace('%','')
            out = float(x)/100
        except:
            out = np.nan
    elif 'x' in x:
        try:
            x = x.replace('x','')
            out = float(x)
        except:
            out = np.nan
    elif 'Ñ' in x:
        try:
            x = x.replace('Ñ',np.nan)
            out = x
        except:
            out = np.nan
    else:
        try:
            out = float(x)
        except:
            out = np.nan       
    return out

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#Call the str_to_float function and apply it to the mis-typed columns in the data using the .apply() function

sat_2017['Participation'] = sat_2017['Participation'].apply(str_to_float)
act_2017['Participation'] = act_2017['Participation'].apply(str_to_float)
act_2017['Composite'] = act_2017['Composite'].apply(str_to_float)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#Check the header of each file

sat_2017.head()
act_2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Check datatypes 
sat_2017.info()
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
# ...

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#Renaming the column headers for SAT and ACT
sat_2017.rename(columns={
    'State':'state',
    'Participation' : 'part_sat_2017',
    'Evidence-Based Reading and Writing':'ebrw_sat_2017',
    'Math':'math_sat_2017',
    'Total':'total_sat_2017'
}, inplace = True)

act_2017.rename(columns={
    'State':'state',
    'Participation' : 'part_act_2017',
    'English':'english_act_2017',
    'Math':'math_act_2017',
    'Reading':'reading_act_2017',
    'Science':'science_act_2017',
    'Composite':'composite_act_2017'
}, inplace = True)

#Display the dataframes to validate updated columns names
sat_2017.head()
act_2017.head()
# Out:
#       state  part_act_2017  english_act_2017  math_act_2017  reading_act_2017  \
# 0  National           0.60              20.3           20.7              21.4
# 1   Alabama           1.00              18.9           18.4              19.7
# 2    Alaska           0.65              18.7           19.8              20.4
# 3   Arizona           0.62              18.6           19.8              20.1
# 4  Arkansas           1.00              18.9           19.0              19.7
#
#    science_act_2017  composite_act_2017
# 0              21.0                21.0
# 1              19.4                19.2
# 2              19.9                19.8
# 3              19.8                19.7
# 4              19.5                19.4

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT 17/18/19|The U.S. state where the test results were aggregated from|
# |part_sat_*year*|float|SAT 17/18/19|The participation rate of students who took the test out of the whole student population|
# |ebrw_sat_*year*|integer|SAT 17/18/19|The total score in the evidence-based reading and writing sub test section|
# |math_sat_*year*|integer|SAT 17/18/19|The total score in the math sub test section|
# |total_sat_*year*|integer|SAT 17/18/19|The total aggregate score of the test (sum total of the math and ebrw section)|
# |state|object|ACT 17/18/19|The U.S. state where the test results were aggregated from|
# |part_act_*year*|float|ACT 17/18/19|The participation rate of students who took the test out of the whole student population|
# |english_act_2017|float|ACT 17|The total score in the english sub test section|
# |math_act_*year*|float|ACT 17|The total score in the math sub test section|
# |reading_act_*year*|float|ACT 17|The total score in the reading sub test section|
# |science_act_*year*|float|ACT 17|The total score in the science sub test section|
# |composite_act_*year*|float|ACT 17/18/19|The total aggregate score of the test (average of the english, math, reading and science sections)|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#Check if the sat_2017 state column matches the contents of the act_2017 column
np.where(sat_2017['state'].isin(act_2017['state']), 'nan', sat_2017.index)
#Check if the act_2017 state column matches the contents of the act_2017 column
np.where(act_2017['state'].isin(sat_2017['state']), 'nan', act_2017.index)
# Out:
# array(['0', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan',
#        'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan',
#        'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan',
#        'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan',
#        'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan',
#        'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], dtype='<U21')

# %%
#ACT row 0 has an extra 'state' value that SAT data does not have 
act_2017['state'][0]
# Out:
# 'National'

# %% [markdown]
# #### Observation: National' row is a summary row and should not be included along with the rest of our metadata

# %%
#Drop the National row entry in ACT data (e.g. row 0)
act_2017.drop(act_2017[act_2017['state'] == 'National'].index, inplace=True)
act_2017.head()
# Out:
#         state  part_act_2017  english_act_2017  math_act_2017  \
# 1     Alabama           1.00              18.9           18.4
# 2      Alaska           0.65              18.7           19.8
# 3     Arizona           0.62              18.6           19.8
# 4    Arkansas           1.00              18.9           19.0
# 5  California           0.31              22.5           22.7
#
#    reading_act_2017  science_act_2017  composite_act_2017
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4
# 5              23.1              22.2                22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Merge both 2017 dataframes and assign to a new variable

combined_2017 = pd.merge(sat_2017, act_2017,how='left')
combined_2017.head()
# Out:
#         state  part_sat_2017  ebrw_sat_2017  math_sat_2017  total_sat_2017  \
# 0     Alabama           0.05            593            572            1165
# 1      Alaska           0.38            547            533            1080
# 2     Arizona           0.30            563            553            1116
# 3    Arkansas           0.03            614            594            1208
# 4  California           0.53            531            524            1055
#
#    part_act_2017  english_act_2017  math_act_2017  reading_act_2017  \
# 0           1.00              18.9           18.4              19.7
# 1           0.65              18.7           19.8              20.4
# 2           0.62              18.6           19.8              20.1
# 3           1.00              18.9           19.0              19.7
# 4           0.31              22.5           22.7              23.1
#
#    science_act_2017  composite_act_2017
# 0              19.4                19.2
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#Save the cleaned and merged data-frame to new csv
combined_2017.to_csv('data/combined_2017.csv', index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Read in the `sat_2018.csv` and `act_2018.csv` files and assign them to appropriately named pandas dataframes. For the **2018 ACT Data**, only the `Composite` scores are available. Repeat the same processes to clean the 2018 data here as you were instructed in the previous sections above.

# %%
#Import data for 2018:
sat_2018 = pd.read_csv('data/sat_2018.csv')
act_2018 = pd.read_csv('data/act_2018.csv')

# %%
#Display info and descriptibe statistics for the new sat file
sat_2018.info()
sat_2018.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# ...

# %%
#Display info and descriptibe statistics for the new act file
act_2018.info()
act_2018.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %% [markdown]
# #### Conclusion: Below is a summary of the data discrepancies that need to be cleaned
# - The datasets contain no null values or incomplete metadata
# - The min/max values of the data seem to be in line with the rest of the dataset with no significant outliers
# - The 2018 data has an incorrect dtype in the participation column similar to the 2017 data
# - The 2018 ACT data has 1 less row than the SAT data which needs to be investigated

# %%
# Call previously defined function to re-type the incorrectly typed columns 

sat_2018['Participation'] = sat_2018['Participation'].apply(str_to_float)
act_2018['Participation'] = act_2018['Participation'].apply(str_to_float)

# %%
# Check modifications to column dtypes
sat_2018.head()
act_2018.head()
sat_2018.info()
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# ...

# %%
#Rename the columns to match the 2017 data file nomenclature

sat_2018.rename(columns={
    'State':'state',
    'Participation' : 'part_sat_2018',
    'Evidence-Based Reading and Writing':'ebrw_sat_2018',
    'Math':'math_sat_2018',
    'Total':'total_sat_2018'
}, inplace = True)

act_2018.rename(columns={
    'State':'state',
    'Participation' : 'part_act_2018',
    'Composite':'composite_act_2018'
}, inplace = True)

# %%
#Locate the additional row in the ACT data by checking if there are any duplicate values
#Create duplicate dataframe
dup = act_2018['state'].duplicated() 
#Fitler dup datarame to only show true values
dup.loc[dup == True]
#Locate the duplicate state
act_2018['state'][20]
# Out:
# 'Maine'

# %%
#Drop additional row in ACT data
act_2018.drop_duplicates(subset = ['state'],inplace=True)

# %%
#Check the count of both data sets for symmetry and completness
act_2018.count()
sat_2018.count()
# Out:
# state             51
# part_sat_2018     51
# ebrw_sat_2018     51
# math_sat_2018     51
# total_sat_2018    51
# dtype: int64

# %%
#Check that the states values all match before a merge
np.where(sat_2018['state'].isin(act_2018['state']), 'nan', sat_2018.index)
np.where(act_2018['state'].isin(sat_2018['state']), 'nan', act_2018.index)
#Check the 8th index for a mismatch in state names
act_2018['state'][8] #District of columbia is spelt with lowercase 'c' in ACT data
# Out:
# 'District of columbia'

# %%
#Rename the state of DoC in the act_2018 data
act_2018.loc[act_2018['state'] == 'District of columbia','state'] = 'District of Columbia'

# %%
#Merge act and sat 2018 dataframes
combined_2018 = pd.merge(sat_2018, act_2018,how='left')
combined_2018.head(9)
# Out:
#                   state  part_sat_2018  ebrw_sat_2018  math_sat_2018  \
# 0               Alabama           0.06            595            571
# 1                Alaska           0.43            562            544
# 2               Arizona           0.29            577            572
# 3              Arkansas           0.05            592            576
# 4            California           0.60            540            536
# 5              Colorado           1.00            519            506
# 6           Connecticut           1.00            535            519
# 7              Delaware           1.00            505            492
# 8  District of Columbia           0.92            497            480
#
#    total_sat_2018  part_act_2018  composite_act_2018
# 0            1166           1.00                19.1
# 1            1106           0.33                20.8
# 2            1149           0.66                19.2
# 3            1169           1.00                19.4
# ...

# %%
#Check the merged dataframes to ensure no discrepancies
combined_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               51 non-null     object
#  1   part_sat_2018       51 non-null     float64
#  2   ebrw_sat_2018       51 non-null     int64
#  3   math_sat_2018       51 non-null     int64
#  4   total_sat_2018      51 non-null     int64
#  5   part_act_2018       51 non-null     float64
#  6   composite_act_2018  51 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.2+ KB

# %%
#Save the combined file to new csv
combined_2018.to_csv('data/combined_2018.csv', index=False)

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#Open both combined csv files in pandas
combined_2017 = pd.read_csv('data/combined_2017.csv')
combined_2018 = pd.read_csv('data/combined_2018.csv')

# %%
#Merge both 2017 and 2018 data into a single csv. file
final = pd.merge(combined_2017, combined_2018,how='left')
final.head()
# Out:
#         state  part_sat_2017  ebrw_sat_2017  math_sat_2017  total_sat_2017  \
# 0     Alabama           0.05            593            572            1165
# 1      Alaska           0.38            547            533            1080
# 2     Arizona           0.30            563            553            1116
# 3    Arkansas           0.03            614            594            1208
# 4  California           0.53            531            524            1055
#
#    part_act_2017  english_act_2017  math_act_2017  reading_act_2017  \
# 0           1.00              18.9           18.4              19.7
# 1           0.65              18.7           19.8              20.4
# 2           0.62              18.6           19.8              20.1
# 3           1.00              18.9           19.0              19.7
# 4           0.31              22.5           22.7              23.1
#
#    science_act_2017  composite_act_2017  part_sat_2018  ebrw_sat_2018  \
# ...

# %%
#Save the combined file to new csv
final.to_csv('data/final.csv',index=False)

# %% [markdown]
# ## 2019 Data Import and Cleaning

# %%
#Import data for 2019
sat_2019 = pd.read_csv('data/sat_2019.csv', encoding = "ISO-8859-1")
act_2019 = pd.read_csv('data/act_2019.csv', encoding = "ISO-8859-1")

# %%
#Display Data
sat_2019.head()
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
#Check data for completenesss
sat_2019.info()
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# #### Observations:
# - Both sets of data have incorrect dtypes for pracitipation rate (similar to 2017/18)
# - SAT data contains 2 additional rows compared to previous years data
# - ACT data contains 1 additional row compared to previous years data

# %%
#Check min and max for any data value issues
sat_2019.describe()
act_2019.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %% [markdown]
# #### Observations: No major issues with the min and max data values

# %%
#Check unique values for any data value issues
sat_2019['EBRW'].unique()
sat_2019['Math'].unique()
sat_2019['Total'].unique()
act_2019['Composite'].unique()
act_2019['Participation'].unique()
sat_2019['Participation Rate'].unique()
# Out:
# array(['7%', '41%', '31%', '6%', '63%', '100%', '94%', '71%', '54%',
#        '66%', '3%', '4%', '5%', '99%', '82%', '81%', '9%', '20%', '95%',
#        '18%', '79%', '51%', '2%', '19%', '22%', '70%', 'Ñ', '68%'],
#       dtype=object)

# %% [markdown]
# #### Observations: There is an additional 'Ñ' string value in the SAT participation rate column that needs to be removed or replaced with a null/NaN value

# %%
#Check for duplicates in the additional rows in the SAT and ACT data
#Create duplicate dataframe
sat_dup = sat_2019['State'].duplicated()
#Fitler dup datarame to only show true values
sat_dup.loc[sat_dup == True] #No duplicates
# Out:
# Series([], Name: State, dtype: bool)

# %%
#Check for duplicates in the additional rows in the SAT and ACT data
#Create duplicate dataframe
act_dup = act_2019['State'].duplicated()
#Fitler dup datarame to only show true values
act_dup.loc[act_dup == True] #No duplicates
# Out:
# Series([], Name: State, dtype: bool)

# %%
#Check the 2019 ACT states for matches in the SAT state
np.where(act_2019['State'].isin(act_2018['state']), 'nan', act_2019.index)
#There is a mismatch for the state in row 51
act_2019['State'][51]
# Out:
# 'National'

# %%
#Check the 2019 ACT states for matches in the SAT state
np.where(sat_2019['State'].isin(sat_2018['state']), 'nan', sat_2019.index)
#There are mismatches for the states in rows 47 and 39
print(sat_2019['State'][47]," ",sat_2019['State'][39])
# Out:
# Virgin Islands   Puerto Rico

# %% [markdown]
# #### 2019 Data cleanliness Observations:
# - Participation rates need to be convered to float
# - Invalid string 'Ñ' found in Participation Rate column in SAT 2019 data that needs to be replaced with NaN values
# - 2019 ACT data contains an additional 'National' row to be dropped
# - 2019 SAT data contains two additional states (Virgin Islands & Puerto Rico) that were not included in the 17/18 datasets and should therefore be dropped for the purpose of this analysis

# %%
#Call the str_to_float function and apply it to the mis-typed SAT columns in the data using the .apply() function
sat_2019['Participation Rate'] = sat_2019['Participation Rate'].apply(str_to_float)

# %%
#Check that str_to_float function properly updated SAT 2019 types and modified 'Ñ' to nan
sat_2019['Participation Rate'].unique()
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  51 non-null     float64
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.2+ KB

# %%
#Call the str_to_float function and apply it to the mis-typed ACT columns in the data using the .apply() function
act_2019['Participation'] = act_2019['Participation'].apply(str_to_float)

# %%
#Check that str_to_float function properly updated ACT 2019 types
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
#Drop the National row entry in ACT 2019 data (e.g. row 0)
act_2019.drop(act_2019[act_2019['State'] == 'National'].index, inplace=True)
#Drop Puerto Rico and Virgin Islands in SAT 2019 data
sat_2019.drop(sat_2019[sat_2019['State'] == 'Puerto Rico'].index, inplace=True)
sat_2019.drop(sat_2019[sat_2019['State'] == 'Virgin Islands'].index, inplace=True)

# %%
#Check the count of both 2019 dataframes
act_2019.count()
sat_2019.count()
# Out:
# State                 51
# Participation Rate    51
# EBRW                  51
# Math                  51
# Total                 51
# dtype: int64

# %%
#Renaming the column headers for SAT and ACT
sat_2019.rename(columns={
    'State':'state',
    'Participation Rate' : 'part_sat_2019',
    'EBRW':'ebrw_sat_2019',
    'Math':'math_sat_2019',
    'Total':'total_sat_2019'
}, inplace = True)

act_2019.rename(columns={
    'State':'state',
    'Participation' : 'part_act_2019',
    'Composite':'composite_act_2019'
}, inplace = True)

sat_2019.head()
act_2019.head()
# Out:
#         state  part_act_2019  composite_act_2019
# 0     Alabama           1.00                18.9
# 1      Alaska           0.38                20.1
# 2     Arizona           0.73                19.0
# 3    Arkansas           1.00                19.3
# 4  California           0.23                22.6

# %%
#Merge both 2019 dataframes and assign to a new variable

combined_2019 = pd.merge(sat_2019, act_2019,how='left')

#Check for any mismatches or null values created during merge
combined_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               51 non-null     object
#  1   part_sat_2019       51 non-null     float64
#  2   ebrw_sat_2019       51 non-null     int64
#  3   math_sat_2019       51 non-null     int64
#  4   total_sat_2019      51 non-null     int64
#  5   part_act_2019       51 non-null     float64
#  6   composite_act_2019  51 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.2+ KB

# %%
#Save the cleaned and merged data-frame to new csv
combined_2019.to_csv('data/combined_2019.csv', index=False)

# %%
#Merge 2019 combined with 2017 and 2018 data
combined_2019 = pd.read_csv('data/combined_2019.csv')
final = pd.merge(final, combined_2019,how='left')
final.head()
# Out:
#         state  part_sat_2017  ebrw_sat_2017  math_sat_2017  total_sat_2017  \
# 0     Alabama           0.05            593            572            1165
# 1      Alaska           0.38            547            533            1080
# 2     Arizona           0.30            563            553            1116
# 3    Arkansas           0.03            614            594            1208
# 4  California           0.53            531            524            1055
#
#    part_act_2017  english_act_2017  math_act_2017  reading_act_2017  \
# 0           1.00              18.9           18.4              19.7
# 1           0.65              18.7           19.8              20.4
# 2           0.62              18.6           19.8              20.1
# 3           1.00              18.9           19.0              19.7
# 4           0.31              22.5           22.7              23.1
#
#    science_act_2017  ...  math_sat_2018  total_sat_2018  part_act_2018  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Transpose the output of pandas describe method to understand statistics overview on each feature
final.describe().transpose()
# Out:
#                     count         mean        std     min       25%      50%  \
# part_sat_2017        51.0     0.398039   0.352766    0.02     0.040     0.38
# ebrw_sat_2017        51.0   569.117647  45.666901  482.00   533.500   559.00
# math_sat_2017        51.0   556.882353  47.121395  468.00   523.500   548.00
# total_sat_2017       51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# part_act_2017        51.0     0.652549   0.321408    0.08     0.310     0.69
# english_act_2017     51.0    20.931373   2.353677   16.30    19.000    20.70
# math_act_2017        51.0    21.182353   1.981989   18.00    19.400    20.90
# reading_act_2017     51.0    22.013725   2.067271   18.10    20.450    21.80
# science_act_2017     51.0    21.450980   1.739353   18.20    19.950    21.30
# composite_act_2017   51.0    21.519608   2.020695   17.80    19.800    21.40
# part_sat_2018        51.0     0.457451   0.373143    0.02     0.045     0.52
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#Define fucntion to calculate standard deviation

def stddev(column):
    mean = column.mean()
    n = final['state'].count()
    sum_diff = 0
    for x in column:
        sum_diff += ((x-mean)**2)
    std_dev = ((1/n)*(sum_diff))**0.5
    return std_dev

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Dictionary comprehension to assign columns names as key and call function for each column to calculate std deviation
#and apply it as a value in the key: values pair
sd = {}
modified_final = final.drop('state',axis = 1)
sd = {key: stddev(modified_final[key]) for key, value in modified_final.items()}
sd
# Out:
# {'part_sat_2017': 0.3492907076664507,
#  'ebrw_sat_2017': 45.21697020437866,
#  'math_sat_2017': 46.65713364485503,
#  'total_sat_2017': 91.58351056778743,
#  'part_act_2017': 0.3182417575123181,
#  'english_act_2017': 2.3304876369363363,
#  'math_act_2017': 1.9624620273436781,
#  'reading_act_2017': 2.0469029314842646,
#  'science_act_2017': 1.7222161451443676,
#  'composite_act_2017': 2.000786081581989,
#  'part_sat_2018': 0.3694661922353942,
#  'ebrw_sat_2018': 47.03460978357609,
#  'math_sat_2018': 47.30194550378352,
#  'total_sat_2018': 93.22742384464433,
#  'part_act_2018': 0.33701735820410317,
#  'composite_act_2018': 2.090779082141178,
#  'part_sat_2019': 0.3836584048685726,
#  'ebrw_sat_2019': 45.792378682545134,
#  'math_sat_2019': 50.78521461840036,
#  'total_sat_2019': 96.24027185617864,
#  'part_act_2019': 0.3417582373703047,
#  'composite_act_2019': 2.172901153595978}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
#Test results for a given column in data
print(stddev(final['part_sat_2017']))
print(np.std(final['part_sat_2017']))
print(final.describe().transpose()['std'][0])
#Confirm test results with a second column in data but this time adding ddof=1 to confirm that pandas std method 
#by default uses the unbiased estimator (N-1 in the denominator)
print(stddev(final['part_act_2017']))
print(np.std(final['part_act_2017']))
print(np.std(final['part_act_2017'],ddof=1))
print(final.describe().transpose()['std'][4])
# Out:
# 0.3492907076664507
# 0.3492907076664507
# 0.35276632270013036
# 0.3182417575123181
# 0.3182417575123181
# 0.32140842015886834
# 0.32140842015886834

# %% [markdown]
# #### Answer: The std value calculated by my function matches the numpy method but is slightly different from the pandas describe method (as seen in cell above). This is because pandas and numpy use different methods by default. Pandas uses the unbiased estimator (N-1 in the denominator) and thus calcualtes a slightly different value for std.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Comparing overall participation rates at national level before drilling down
participation = final.loc[:,['state','part_sat_2017','part_sat_2018','part_sat_2019','part_act_2017','part_act_2018','part_act_2019']]
participation.describe()
# Out:
#        part_sat_2017  part_sat_2018  part_sat_2019  part_act_2017  \
# count      51.000000      51.000000      51.000000      51.000000
# mean        0.398039       0.457451       0.490588       0.652549
# std         0.352766       0.373143       0.387476       0.321408
# min         0.020000       0.020000       0.020000       0.080000
# 25%         0.040000       0.045000       0.055000       0.310000
# 50%         0.380000       0.520000       0.540000       0.690000
# 75%         0.660000       0.775000       0.820000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        part_act_2018  part_act_2019
# count      51.000000      51.000000
# mean        0.617255       0.586667
# std         0.340371       0.345159
# min         0.070000       0.060000
# 25%         0.285000       0.245000
# 50%         0.660000       0.540000
# 75%         1.000000       1.000000
# max         1.000000       1.000000

# %% [markdown]
# #### Trends on the participation rates across the data
# - On avg. the SAT has signifcantly lower participation rates than the ACT (39%, 46% nd 49% rates for the SAT in 17/18/19 respectively compared with 65%, 62% and 58% rates for the ACT in 17/18/29 respectively)
# - SAT participation rate increased by ~10% between 17/10 whereas the ACT decreased by ~7% showing a historical change in trend

# %%
participation.sort_values('part_sat_2017').head(5)
participation.sort_values('part_sat_2018').head(5)
participation.sort_values('part_act_2017').head(5)
participation.sort_values('part_act_2018').head(5)
participation.sort_values('part_sat_2019').head(5)
participation.sort_values('part_act_2019').head(5)
# Out:
#             state  part_sat_2017  part_sat_2018  part_sat_2019  part_act_2017  \
# 19          Maine           0.95           0.99           0.99           0.08
# 39   Rhode Island           0.71           0.97           1.00           0.21
# 7        Delaware           1.00           1.00           1.00           0.18
# 29  New Hampshire           0.96           0.96           0.95           0.18
# 38   Pennsylvania           0.65           0.70           0.70           0.23
#
#     part_act_2018  part_act_2019
# 19           0.07           0.06
# 39           0.15           0.12
# 7            0.17           0.13
# 29           0.16           0.14
# 38           0.20           0.17

# %% [markdown]
# #### Low participation rates by state:
#
# SAT Lowest 5 states:
# - In 2017, the 5 states with the lowest participation were North Dakota, Mississippi, Iowa, Missouri and Utah
# - In 2018, the 5 states with the lowest particiaption were North Dakota, Wymoing, South Dakota, Nebraska and Wisconsin
# - In 2019, the 5 states with the lowest particiaption were North Dakota, Wymoing, South Dakota, Nebraska and Wisconsin
#
# ACT Lowest 5 states:
# - In 2017, the 5 states with the lowest participation were Maine, NH, Delaware, RhodeIsland and Pennsylvania
# - In 2018, the 5 states with the lowest particiaption were Maine, Rhode Island , NH, Delaware and Pennsylvania
# - In 2019, the 5 states with the lowest particiaption were Maine, Rhode Island , Delaware, NH and Pennsylvania
#
# It is also worth noting that states with low SAT participation generally have high ACT participaton and vice versa

# %%
participation.sort_values('part_sat_2017',ascending = False).head(5)
participation.sort_values('part_sat_2018',ascending = False).head(5)
participation.sort_values('part_act_2017',ascending = False).head(20)
participation.sort_values('part_act_2018',ascending = False).head(20)
participation.sort_values('part_sat_2019',ascending = False).head(10)
participation.sort_values('part_act_2019',ascending = False).head(20)
# Out:
#              state  part_sat_2017  part_sat_2018  part_sat_2019  \
# 0          Alabama           0.05           0.06           0.07
# 17        Kentucky           0.04           0.04           0.04
# 49       Wisconsin           0.03           0.03           0.03
# 44            Utah           0.03           0.04           0.04
# 42       Tennessee           0.05           0.06           0.07
# 36        Oklahoma           0.07           0.08           0.22
# 35            Ohio           0.12           0.18           0.19
# 33  North Carolina           0.49           0.52           0.51
# 28          Nevada           0.26           0.23           0.20
# 27        Nebraska           0.03           0.03           0.03
# 26         Montana           0.10           0.10           0.09
# 24     Mississippi           0.02           0.03           0.03
# 18       Louisiana           0.04           0.04           0.05
# 50         Wyoming           0.03           0.03           0.03
# ...

# %% [markdown]
# #### High participation rates by state:
#
# SAT highest 5 states:
# - In 2017, the 5 states with the highest participation were DoC, Michigan, Connecticut, Delaware and NH
# - In 2018, the 5 states with the highest particiaption were Colorado, Connecticut, Delaware, Michigan and Idaho. All of these states had an 100% participation record.
# - In 2019, the 8 states with the highest particiaption were Rhode Island, Illinois, Michigan, Colorado, Connecticut, Delaware, Florida and Idaho. All of these states had an 100% participation record.
#
# ACT highest 5 states:
# - In 2017, 17 states have 100% participation. It is worth noting they consistently have very low SAT participation rates (with the exception of the Carolinas and Hawaii which are between 50%-55% on the SAT in both years). Also 15 of these 17 states overlap with states that have 100% participation rates for the ACT in 2018
# - In 2018, 17 states have 100% participation. It is worth noting they consistently have very low SAT participation rates
# - In 2019, 15 states have 100% participation. It is worth noting they consistently have very low SAT participation rates. All 15 of these 100% participartion states overlap 100% with the states that have 100% participation  for the ACT in 2018.
#
# Additional Notes
# - It is also worth noting that states with low SAT participation generally have high act participaton and vice versa when looking at data across both tests and years.
# - Colorado shows an interesting trend as it has 100% particiation for the SAT in 2018 & 2019 but only 11% in 2017. Comparing this with 100% participation for the ACT in 2017 and only 30% in 2018 and 27% in 2019, I would surmise that Colorado modified their statewide standardized testing policies between 2017 and 2018.Illinois is showing a similar trend. To be confirmed with supplement research.

# %%
scores = final.loc[:,['state','total_sat_2017','total_sat_2018','total_sat_2019','composite_act_2017','composite_act_2018','composite_act_2019']]
scores.sort_values('total_sat_2017').head(5)
scores.sort_values('total_sat_2018').head(5)
scores.sort_values('composite_act_2017').head(5)
scores.sort_values('composite_act_2018').head(5)
scores.sort_values('total_sat_2019').head(5)
scores.sort_values('composite_act_2019').head(5)
# Out:
#              state  total_sat_2017  total_sat_2018  total_sat_2019  \
# 28          Nevada            1116            1140            1156
# 24     Mississippi            1242            1236            1237
# 40  South Carolina            1064            1070            1030
# 18       Louisiana            1198            1210            1200
# 0          Alabama            1165            1166            1143
#
#     composite_act_2017  composite_act_2018  composite_act_2019
# 28                17.8                17.7                17.9
# 24                18.6                18.6                18.4
# 40                18.7                18.3                18.8
# 18                19.5                19.2                18.8
# 0                 19.2                19.1                18.9

# %% [markdown]
# #### Low total/composite scores by state:
#
# SAT lowest 5 states:
# - In 2017, the 5 states with the lowest scores were DoC, Delaware, Idaho, Michigan and Maine
# - In 2018, the 5 states with the lowest particiaption were DoC, Delaware, West Virginia, Idaho and Utah. 3 of these states  overlap with 2017 data.
# - In 2019, the 5 states with the lowest participation were West Virginia, Oklahoma,DoC, Delaware and Idaho. 4 of these overlap with 2018 data.
#
# ACT lowest 5 states:
# - In 2017, the 5 states with the lowest scores were Nevada, Mississipi, South Carolina, Hawaii and North Carolina
# - In 2018, the 5 states with the lowest scores were Nevada, South Carolina, Mississipi, Hawaii and Alabama. 4 of these overlap with 2017 data.
# - In 2019, the 5 states with the lowest scores were Nevada, Mississippi, South Carolina, Louisiana, Alabama. 4 of these overlap with 2018 data.

# %%
scores.sort_values('total_sat_2017',ascending = False).head(5)
scores.sort_values('total_sat_2018', ascending = False).head(5)
scores.sort_values('composite_act_2017',ascending = False).head(5)
scores.sort_values('composite_act_2018', ascending = False).head(5)
scores.sort_values('total_sat_2019', ascending = False).head(5)
scores.sort_values('composite_act_2019', ascending = False).head(5)
# Out:
#             state  total_sat_2017  total_sat_2018  total_sat_2019  \
# 21  Massachusetts            1107            1125            1120
# 6     Connecticut            1041            1053            1046
# 29  New Hampshire            1052            1063            1059
# 39   Rhode Island            1062            1018             995
# 32       New York            1052            1068            1064
#
#     composite_act_2017  composite_act_2018  composite_act_2019
# 21                25.4                25.5                25.5
# 6                 25.2                25.6                25.5
# 29                25.5                25.1                25.0
# 39                24.0                24.2                24.7
# 32                24.2                24.5                24.5

# %% [markdown]
# #### High total/composite scores by state:
#
# SAT highest 5 states:
# - In 2017, the 5 states with the highest scores were Minnesota, Wisconsin, Iowa, Missouri, Kansas
# - In 2018, the 5 states with the hgihest particiaption were Minnesota, Wisconsin, North Dakota, Iowa, Kansas. 4 of these overlap with 2017 data.
# - In 2019, the 5 states with the hgihest particiaption were Minnesota, Wisconsin, South Dakota, North Dakota and Nebraska. 3 of these overlap with 2018 data.
#
# ACT highest 5 states:
# - In 2017, the 5 states with the highest scores were NH, Massachusetts, Connecticut, Maine and DoC
# - In 2018, the 5 states with the highest scores were Connecticut, Massachusettes, NH, NY, Michigan. 3 of these overlap with 2018 data.
# - In 2019, the 5 states with the highest scores were Massachusettes,Connecticut, NH,Rhode Island and NY

# %%
participation.head()
participation.loc[participation['part_sat_2017'] == 1.0,:]
participation.loc[participation['part_sat_2018'] == 1.0,:]
participation.loc[participation['part_act_2017'] == 1.0,:]
participation.loc[participation['part_act_2018'] == 1.0,:]
participation.loc[participation['part_sat_2019'] == 1.0,:]
participation.loc[participation['part_act_2019'] == 1.0,:]
# Out:
#              state  part_sat_2017  part_sat_2018  part_sat_2019  \
# 0          Alabama           0.05           0.06           0.07
# 3         Arkansas           0.03           0.05           0.06
# 17        Kentucky           0.04           0.04           0.04
# 18       Louisiana           0.04           0.04           0.05
# 24     Mississippi           0.02           0.03           0.03
# 26         Montana           0.10           0.10           0.09
# 27        Nebraska           0.03           0.03           0.03
# 28          Nevada           0.26           0.23           0.20
# 33  North Carolina           0.49           0.52           0.51
# 35            Ohio           0.12           0.18           0.19
# 36        Oklahoma           0.07           0.08           0.22
# 42       Tennessee           0.05           0.06           0.07
# 44            Utah           0.03           0.04           0.04
# 49       Wisconsin           0.03           0.03           0.03
# ...

# %% [markdown]
# #### Additional Questions (1/2)
# Do any states with 100% participation on a given test have a rate change year-to-year?
#
# SAT:
# - Florida's participation varies widely from 83% in 2017 to 56% in 2018 to 100% in 2019
# - Idaho's participation improved by 7% from 93% in 2017 to 100% in 2018 & 2019
# - Colorado participation improved from 11% in 2017 to 100% in 2018 & 2019. As mentioned earlier, clearly Colorado undergoes some form of change in the requirements for statewide standardized testing from the ACT to the SAT. To be confirmed by qualitiative research.
# - Illinois shows a similar trend to Colorado (9% in 2017, 99% in 2018 and 100% in 2019)
# - Rhode Island shows continuous improvement from 71% in 2017 to 97% in 2018 to 100% in 2019
#
# ACT
# - The ACT data again confirms the hypothesis on Colorado and Illinois
# - Ohio and Nebraska both saw signifcant improvements in participation from 2017 to 2018 of 25% and 16% respectively
# - Missouri and South Carolina both go from 100% in 2017 & 2018 to 82% and 78% respectively in 2019.
# - All states with 100% participation in 2019 also had 100% participation in 2018

# %%
participation.loc[(participation['part_sat_2017'] > 0.5) & (participation['part_act_2017'] > 0.5),:]
participation.loc[(participation['part_sat_2018'] > 0.5) & (participation['part_act_2018'] > 0.5),:]
participation.loc[(participation['part_sat_2019'] > 0.5) & (participation['part_act_2019'] > 0.5),:]
# Out:
#              state  part_sat_2017  part_sat_2018  part_sat_2019  \
# 9          Florida           0.83           0.56           1.00
# 11          Hawaii           0.55           0.56           0.54
# 33  North Carolina           0.49           0.52           0.51
# 40  South Carolina           0.50           0.55           0.68
#
#     part_act_2017  part_act_2018  part_act_2019
# 9            0.73           0.66           0.54
# 11           0.90           0.89           0.80
# 33           1.00           1.00           1.00
# 40           1.00           1.00           0.78

# %% [markdown]
# #### Additional Questions (2/2)
# Do any states show have >50% participation on both tests either year?
#
# 2017
# - Yes in 2017 Florida, Georgia and Hawaii all achieved >50% participation on both the SAT and ACT
#
# 2018
# - Yes in 2018 Florida, Georgia, Hawaii and North/South Carolina all achieved >50% participation on both the SAT and ACT
#
# 2019
# - Yes in 2019 Florida, Hawaii and North/South Carolina all achieved >50% participation on both the SAT and ACT

# %% [markdown]
# #### Additional EDA section to identify states with large variances in participation between 2017 and 2019

# %%
#Checking the states that had the largest YoY changes in same test participation
participation['yoy_delta_part_sat'] = participation['part_sat_2019'] - participation['part_sat_2017'] 
participation['yoy_delta_part_act'] = participation['part_act_2019'] - participation['part_act_2017'] 
participation.loc[(abs(participation['yoy_delta_part_sat']) > 0.2),:]
# Out:
#             state  part_sat_2017  part_sat_2018  part_sat_2019  part_act_2017  \
# 5        Colorado           0.11           1.00           1.00           1.00
# 13       Illinois           0.09           0.99           1.00           0.93
# 39   Rhode Island           0.71           0.97           1.00           0.21
# 48  West Virginia           0.14           0.28           0.99           0.69
#
#     part_act_2018  part_act_2019  yoy_delta_part_sat  yoy_delta_part_act
# 5            0.30           0.27                0.89               -0.73
# 13           0.43           0.35                0.91               -0.58
# 39           0.15           0.12                0.29               -0.09
# 48           0.65           0.49                0.85               -0.20

# %%
participation.loc[(abs(participation['yoy_delta_part_act']) > 0.2),:]
# Out:
#              state  part_sat_2017  part_sat_2018  part_sat_2019  \
# 1           Alaska           0.38           0.43           0.41
# 5         Colorado           0.11           1.00           1.00
# 13        Illinois           0.09           0.99           1.00
# 35            Ohio           0.12           0.18           0.19
# 40  South Carolina           0.50           0.55           0.68
#
#     part_act_2017  part_act_2018  part_act_2019  yoy_delta_part_sat  \
# 1            0.65           0.33           0.38                0.03
# 5            1.00           0.30           0.27                0.89
# 13           0.93           0.43           0.35                0.91
# 35           0.75           1.00           1.00                0.07
# 40           1.00           1.00           0.78                0.18
#
#     yoy_delta_part_act
# 1                -0.27
# 5                -0.73
# 13               -0.58
# 35                0.25
# 40               -0.22

# %% [markdown]
# #### States of Interest after EDA
# - States that seem to have relatively high participation across both tests: Florida, Georgia, Hawaii and North/South Carolina
# - States that potentially altered standardized policies between 17/18: Colorado, Illinois
# - States that had signifcant differences in same-test participation b/w 17/19:
#
#     SAT: West Virgina Rhode Island
#
#     ACT: Ohio, Alaska,South Carolina

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
#Import seaborn module
import seaborn as sns

# %%
# Establish size of figure.
plt.figure(figsize=(18,14))

# Generate 10 variables of 200 random observations.
corr = final.corr()
corr
# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask=mask, vmax=.3, square=True, annot=True,cmap="Greens")
    
# Titles and naming
plt.title('Correlation between all numeric SAT & ACT data columns',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Correlation between all numeric SAT & ACT data columns')

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
#Define function to subplot histograms
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels,bins):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(figsize=(10,10),nrows=nrows, ncols=2) # You'll want to specify your figsize
    fig.tight_layout()  #Clean up the grid layout between subplots
    fig.subplots_adjust(hspace=0.6, wspace=0.3, ) #Add whitespace between subplots
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column],bins=bins) # feel free to add more settings
        ax[i].set_title(list_of_titles[i])# Set titles, labels, etc here for each subplot
        ax[i].set_xlabel(list_of_xlabels[i])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Call subplot function to plot participation rates for SAT & ACT
subplot_histograms(final,['part_sat_2017','part_act_2017','part_sat_2018','part_act_2018','part_sat_2019','part_act_2019'],
                   ['2017 SAT Participation Histogram','2017 ACT Participation Histogram',
                   '2018 SAT Participation Histogram','2018 ACT Participation Histogram','2019 SAT Participation Histogram','2019 ACT Participation Histogram'],
                   ['Participation Rates (%)','Participation Rates (%)','Participation Rates (%)','Participation Rates (%)','Participation Rates (%)','Participation Rates (%)'],8)

# %% [markdown]
# All of the plotted participation data is not normally distributed.The SAT and ACT plots roughly mirror eachother
#
# SAT vs. ACT Comparison
# - The SAT tests have near 0 participation rates in 15-20 states in 2017/18/19
# - The ACT tests have poor participation rates (<20% participation) in under 5 states in 2017/18/19
# - On the other hand the ACT test has near 100% participation rates in greater than 15 states across all three years
#
# 2017 vs. 2018 vs. 2019 Same Test Comparison
# - SAT: There are light variances in the 20%,30%,40% and 50% participation bins which could be further investigated but given we're analyzing aggregate data at the state level, these slight variances in bins acrosss years can likely be considered negligeable for the purpose of this analysis.
# - ACT: Same as above. Similar distributions across all 3 years with no major differences to callout that will be impacful to this analysis.

# %%
# Call subplot function to plot Math scores for SAT & ACT
subplot_histograms(final,['math_sat_2017','math_act_2017','math_sat_2018','math_sat_2019'],
                   ['2017 SAT Math Scores','2017 ACT Math Scores',
                   '2018 SAT Math Scores','2019 SAT Math Scores'],
                   ['Total Math Score','Total Math Score','Total Math Score','Total Math Score'],8)

# %% [markdown]
# All of the plotted Math score data is not normally distributed.
#
# SAT vs. ACT Comparison
# - The distribution of ACT math scores tends to be closer to the mean than most of the distributions in the SAT datasets
# 2017 vs 2018 vs. 2019 Same Test Comparison
# - Beteen 17/18 there is a large increase in the lowest Math score bin (~475)
# - Between 18/19 there is a decrease in the lowest bin (~475), an increase in the mean bin (~550) and an increase in the upper two bins (~600 and ~625)

# %%
# Call subplot function to plot reading/verbal scores for SAT & ACT
subplot_histograms(final,['ebrw_sat_2017','english_act_2017','ebrw_sat_2018','reading_act_2017','ebrw_sat_2019'],
                   ['2017 SAT Reading & Writing Scores','2017 ACT English Scores',
                   '2018 SAT Reading & Writing Scores','2017 ACT Reading Scores','2019 SAT Reading & Writing Scores'],
                   ['Total Reading & Writing Score','Total English Score','Total Reading & Writing Score','Total Reading Score','Total Reading & Writing Score'],8)

# %% [markdown]
# All of the plotted Reading & Writing score data is not normally distributed.
#
# 2017 vs. 2018 vs. 2019 Same Test SAT Comparison
# - The distributions of reading & writing scores are near identifical with a slight decrease in the ~525 and ~575 score bins and increase in the ~475 and ~500 score bins
# - The 2019 data becomes more evenly distributed than the previous years (still maintaining the trend from 17/18 that a large concentration of states score in the maximum range on this section)
# 2017 SAT vs. ACT Comparison
# - Given the ACT is broken out into two subtest sections, it is likely a more direct comparison to take the composite of both these categories before comapring it to the SAT reading and writing section - luckily the ACT english & reading distributions are nearly identical and can therefore can be directly compared to the SAT scores
# - The ACT scores are generally more evenly distributed whereas the SAT score distributions are more weighted to the poor perfroming sub ~575 scores.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
#Define function to plot xy scatter when given list of columsna and axis titles
def xy_scatter(column_list,title_list):
    # Establish the size of the figure.
    plt.figure(figsize=(13, 9))

    #Add random colors to make plot easier on the eye
    colors = np.random.rand(len(final['part_act_2017']))
    
    # Create scatterplot 
    plt.scatter(final[column_list[0]],final[column_list[1]],c=colors)

    #Create titles and x,y axis labels
    string = title_list[0] + " vs. " + title_list[1] + " - XY Scatterplot"
    plt.title(string,fontsize=17)
    plt.ylabel(title_list[1], fontsize = 12)
    plt.xlabel(title_list[0], fontsize = 12);

# %%
#SAT vs. ACT math scores for 2017
xy_scatter(['math_sat_2017','math_act_2017'],['2017 SAT Math Score','2017 ACT Math Score'])

# %% [markdown]
# #### Observations: No correlation between two variables

# %%
#SAT vs. ACT verbal/reading scores for 2017
xy_scatter(['ebrw_sat_2017','reading_act_2017'],['2017 SAT Reading & Writing Score','2017 ACT Reading Score'])

# %% [markdown]
# #### Observations: No correlation between two variables

# %%
#SAT vs. ACT total/composite scores for 2017
xy_scatter(['total_sat_2017','composite_act_2017'],['2017 SAT Total Score','2017 ACT Composite Score'])

# %% [markdown]
# #### Observations: No correlation between two variables

# %%
#Total scores for SAT 2017 vs. 2018
xy_scatter(['total_sat_2017','total_sat_2018'],['2017 SAT Total Score','2018 SAT Total Score'])

# %% [markdown]
# #### Observations: Vairables are correlated. A high state SAT score in 2017 is correlated to a high state SAT score in 2018.

# %%
#Composite scores for ACT 2017 vs. 2018
xy_scatter(['composite_act_2017','composite_act_2018'],['2017 ACT Composite Score','2018 ACT Composite Score'])

# %% [markdown]
# #### Observations: Vairables are correlated. A high state ACT score in 2017 is correlated to a high state ACT score in 2018.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
#Plot boxplot of participation rates for both years across ACT & SAT
plt.figure(figsize=(14,8))
df_part = final[['part_sat_2017','part_act_2017','part_sat_2018','part_act_2018','part_sat_2019','part_act_2019']]
sns.boxplot(x="variable", y="value", data=pd.melt(df_part))
plt.title('SAT vs. ACT Participation rates by year',fontsize=17)
plt.ylabel('Value', fontsize = 12)
plt.xlabel('Participation Rate Variables', fontsize = 12);

# %% [markdown]
# #### Observations:
#
# Matches previous observations that ACT participation rates are much higher than the SAT and often are near 100%. A signifcant amount of ACT participation rates were observed as 100% which explains the proximity of the IQR to the maximum on the ACT plots. Similarly, many SAT particiaption rates were observed as near 0% which is why the reverse trend can be observed on the SAT plots (e.g. bottom of IQR near minimums)

# %%
#Plot boxplot of SAT EBRW & Math scores for both years 
plt.figure(figsize=(14,8))
df_part = final[['ebrw_sat_2017','ebrw_sat_2018','ebrw_sat_2019','math_sat_2017','math_sat_2018','math_sat_2019']]
sns.boxplot(x="variable", y="value", data=pd.melt(df_part))
plt.title('SAT Sub Test Section Scores by year',fontsize=17)
plt.ylabel('Value', fontsize = 12)
plt.xlabel('\nSub Test Score Variables', fontsize = 12);

# %% [markdown]
# #### Observations:
# EBRW
#
# - There is a decreasing trend in the EBRW scores (lower YoY maximums, lower medians).
# - The IQR has expanded between 2017 and 2019
#
# Math
#
# - Math scores have varied up and down between 17/18/19 with an overall (albeit slight) downtrend over the 3 years (lower mins, lower maxs and lower median)
# - The IQR has expanded between 2017 and 2019

# %%
#Plot boxplot of SAT total scores for both years 
plt.figure(figsize=(12,7))
df_part = final[['total_sat_2017','total_sat_2018','total_sat_2019']]
sns.boxplot(x="variable", y="value", data=pd.melt(df_part))
plt.title('Total SAT Scores by year',fontsize=17)
plt.ylabel('Value', fontsize = 12)
plt.xlabel('\nTotal Score Variables', fontsize = 12);

# %% [markdown]
# #### Observations:
#
# - There is a slight decrease in trend over the three years (lower mins, lower maxs and lower medians)
# - The IQR range has  increased from 2017 to 2019.

# %%
#Plot boxplot of all ACT scores for both years 
plt.figure(figsize=(15,8))
df_part = final[['english_act_2017','math_act_2017','reading_act_2017','science_act_2017','science_act_2017']]
sns.boxplot(x="variable", y="value", data=pd.melt(df_part))
plt.title('ACT Scores by year',fontsize=17)
plt.ylabel('Value', fontsize = 12)
plt.xlabel('\nScore Variables', fontsize = 12);

# %% [markdown]
# #### Observations
# - Not enough data to compare trend of boxplots YoY for sub test categories

# %%
#Plot boxplot of all ACT scores for both years 
plt.figure(figsize=(15,8))
df_part = final[['composite_act_2017','composite_act_2018','composite_act_2019']]
sns.boxplot(x="variable", y="value", data=pd.melt(df_part))
plt.title('ACT Scores by year',fontsize=17)
plt.ylabel('Value', fontsize = 12)
plt.xlabel('\nScore Variables', fontsize = 12);

# %% [markdown]
# #### Observations:
#
# - Negligeable variance in composite scores YoY

# %% [markdown]
# ## Additional Visualizations

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#Correlation chart specifically focusing on SAT and ACT participation
participate = final.loc[:,['state','part_sat_2017','part_sat_2018','part_sat_2019','part_act_2017','part_act_2018','part_act_2019']]
# Establish size of figure.
plt.figure(figsize=(18,14))

# Generate 10 variables of 200 random observations.
correlation = participate.corr()
correlation
# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(correlation)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(correlation, mask=mask, vmax=.3, square=True, annot=True,cmap="Greens")
    
# Titles and naming
plt.title('Correlation between SAT & ACT participation rates',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Correlation between SAT & ACT participation rates')

# %% [markdown]
# #### Observations:
# - SAT 2017 vs. 2018 participation rates exhibit a strong correlation
# - ACT 2017 vs. 2018 participation rates exhibit a strong correlation
# - ACT vs. SAT participaton rates also exhibit a relative negative correlation which could infer that various states only mandate 1 of the exams to be taken

# %%
#Alter the xy scatter function to include vertical lines calling out quadrants for >50% participation
#Define function to plot xy scatter when given list of columsn and axis titles
def xy_scatter_two(column_list,title_list):
    # Establish the size of the figure.
    plt.figure(figsize=(13, 9))

    #Add random colors to make plot easier on the eye
    colors = np.random.rand(len(final['part_act_2017']))
    
    # Create scatterplot 
    fig = plt.scatter(final[column_list[0]],final[column_list[1]],c=colors)
    
    #Create vertical lines
    plt.axvline(x=0.5,ymin = 0.465, ymax = 1.0,color = 'red')
    
    #Create horizontal line
    plt.axhline(y=0.5,xmin = 0.49, xmax = 1.0,color = 'red')

    #Create titles and x,y axis labels
    string = title_list[0] + " vs. " + title_list[1] + " - XY Scatterplot"
    plt.title(string,fontsize=17)
    plt.ylabel(title_list[1], fontsize = 12)
    plt.xlabel(title_list[0], fontsize = 12);

# %%
#SAT vs. ACT particiption rates 2017
xy_scatter(['part_sat_2017','part_act_2017'],['2017 SAT Participation','2017 ACT Participation'])

# %%
#SAT vs. ACT particiption rates 2017
xy_scatter_two(['part_sat_2017','part_act_2017'],['2017 SAT Participation','2017 ACT Participation'])

# %%
participation.loc[(participation['part_sat_2017'] > 0.5) & (participation['part_act_2017'] > 0.5),:]
# Out:
#       state  part_sat_2017  part_sat_2018  part_sat_2019  part_act_2017  \
# 9   Florida           0.83           0.56           1.00           0.73
# 10  Georgia           0.61           0.70           0.71           0.55
# 11   Hawaii           0.55           0.56           0.54           0.90
#
#     part_act_2018  part_act_2019  yoy_delta_part_sat  yoy_delta_part_act
# 9            0.66           0.54                0.17               -0.19
# 10           0.53           0.49                0.10               -0.06
# 11           0.89           0.80               -0.01               -0.10

# %% [markdown]
# #### Observations:
# - XY Scatter further illustares the negative correlation between SAT and ACT particiaption
# - As observed earlier in the data, this is not always true for some states that have >50% participation on both tests. Florida, Georgia and Hawaai can be seen in the upper right qudrant above as well as in the filtered dataframe directly above this cell.

# %%
#SAT vs. ACT particiption rates 2018
xy_scatter_two(['part_sat_2018','part_act_2018'],['2018 SAT Participation','2018 ACT Participation'])

# %%
participation.loc[(participation['part_sat_2018'] > 0.5) & (participation['part_act_2018'] > 0.5),:]
# Out:
#              state  part_sat_2017  part_sat_2018  part_sat_2019  \
# 9          Florida           0.83           0.56           1.00
# 10         Georgia           0.61           0.70           0.71
# 11          Hawaii           0.55           0.56           0.54
# 33  North Carolina           0.49           0.52           0.51
# 40  South Carolina           0.50           0.55           0.68
#
#     part_act_2017  part_act_2018  part_act_2019  yoy_delta_part_sat  \
# 9            0.73           0.66           0.54                0.17
# 10           0.55           0.53           0.49                0.10
# 11           0.90           0.89           0.80               -0.01
# 33           1.00           1.00           1.00                0.02
# 40           1.00           1.00           0.78                0.18
#
#     yoy_delta_part_act
# 9                -0.19
# 10               -0.06
# 11               -0.10
# 33                0.00
# 40               -0.22

# %% [markdown]
# #### Observations:
# - XY Scatter further illustares the negative correlation between SAT and ACT particiaption
# - As observed earlier in the data, this is not always true for some states that have >50% participation on both tests. Florida, Georgia, Hawaii and North & South Carolina can be seen in the upper right qudrant above as well as in the filtered dataframe directly above this cell.

# %%
#SAT vs. ACT particiption rates 2019
xy_scatter_two(['part_sat_2019','part_act_2019'],['2019 SAT Participation','2019 ACT Participation'])

# %%
participation.loc[(participation['part_sat_2019'] > 0.5) & (participation['part_act_2019'] > 0.5),:]
# Out:
#              state  part_sat_2017  part_sat_2018  part_sat_2019  \
# 9          Florida           0.83           0.56           1.00
# 11          Hawaii           0.55           0.56           0.54
# 33  North Carolina           0.49           0.52           0.51
# 40  South Carolina           0.50           0.55           0.68
#
#     part_act_2017  part_act_2018  part_act_2019  yoy_delta_part_sat  \
# 9            0.73           0.66           0.54                0.17
# 11           0.90           0.89           0.80               -0.01
# 33           1.00           1.00           1.00                0.02
# 40           1.00           1.00           0.78                0.18
#
#     yoy_delta_part_act
# 9                -0.19
# 11               -0.10
# 33                0.00
# 40               -0.22

# %% [markdown]
# #### Observations:
# - XY Scatter further illustares the negative correlation between SAT and ACT particiaption
# - As observed earlier in the data, this is not always true for some states that have >50% participation on both tests. Florida, Hawaii and North & South Carolina can be seen in the upper right qudrant above as well as in the filtered dataframe directly above this cell.

# %%
#SAT particiption rates 2017 vs 2018
xy_scatter(['part_sat_2017','part_sat_2018'],['2017 SAT Participation','2018 SAT Participation'])

# %%
participation.loc[(participation['part_sat_2017'] < 0.2) & (participation['part_sat_2018'] > 0.8),:]
# Out:
#        state  part_sat_2017  part_sat_2018  part_sat_2019  part_act_2017  \
# 5   Colorado           0.11           1.00            1.0           1.00
# 13  Illinois           0.09           0.99            1.0           0.93
#
#     part_act_2018  part_act_2019  yoy_delta_part_sat  yoy_delta_part_act
# 5            0.30           0.27                0.89               -0.73
# 13           0.43           0.35                0.91               -0.58

# %% [markdown]
# #### Observations:
# - XY Scatter further illustares the a posititve correlation between 2017 SAT and 2018 SAT particpation rates
# - The two outlier's seen on this plot are are represented by Colorado and Illinois. These states have also previously been identfied as having large variances in YoY SAT & ACT participation, likely due to policy changes. The following chart will further confirm this theory.

# %%
#ACT particiption rates 2017 vs 2018
xy_scatter(['part_act_2017','part_act_2018'],['2017 ACT Participation','2018 ACT Participation'])

# %%
participation.loc[(participation['part_act_2017'] > 0.6) & (participation['part_act_2018'] < 0.45),:]
# Out:
#        state  part_sat_2017  part_sat_2018  part_sat_2019  part_act_2017  \
# 1     Alaska           0.38           0.43           0.41           0.65
# 5   Colorado           0.11           1.00           1.00           1.00
# 13  Illinois           0.09           0.99           1.00           0.93
#
#     part_act_2018  part_act_2019  yoy_delta_part_sat  yoy_delta_part_act
# 1            0.33           0.38                0.03               -0.27
# 5            0.30           0.27                0.89               -0.73
# 13           0.43           0.35                0.91               -0.58

# %% [markdown]
# #### Observations:
# - XY Scatter further illustares the a posititve correlation between 2017 ACT and 2018 ACT particpation rates
# - The three outlier's seen on this plot are represented by Colorado, Illinois and Alaska. Colorado and Illinois have also previously been identfied as having large variances in YoY SAT & ACT participation, likely due to policy changes.
# - Alaska is a state that would also require further investigation due to its large YoY variances on the ACT (as mentioned earlier)

# %%
#SAT particiption rates 2017 vs 2019
xy_scatter(['part_sat_2017','part_sat_2019'],['2017 SAT Participation','2019 SAT Participation'])

# %%
participation.loc[(participation['part_sat_2019'] > 0.8) & (participation['part_sat_2017'] < 0.2),:]
# Out:
#             state  part_sat_2017  part_sat_2018  part_sat_2019  part_act_2017  \
# 5        Colorado           0.11           1.00           1.00           1.00
# 13       Illinois           0.09           0.99           1.00           0.93
# 48  West Virginia           0.14           0.28           0.99           0.69
#
#     part_act_2018  part_act_2019  yoy_delta_part_sat  yoy_delta_part_act
# 5            0.30           0.27                0.89               -0.73
# 13           0.43           0.35                0.91               -0.58
# 48           0.65           0.49                0.85               -0.20

# %% [markdown]
# #### Observations:
# - XY Scatter further illustrates a posititve correlation between 2017 SAT and 2019 SAT participation rates
# - The three outlier's seen on this plot are represented by Colorado, Illinois and West Virgina as seen in the dataframe directly above this cell.

# %%
#ACT particiption rates 2017 vs 2019
xy_scatter(['part_act_2017','part_act_2019'],['2017 ACT Participation','2019 ACT Participation'])

# %%
participation.loc[(participation['part_act_2019'] < 0.4) & (participation['part_act_2017'] > 0.8),:]
# Out:
#        state  part_sat_2017  part_sat_2018  part_sat_2019  part_act_2017  \
# 5   Colorado           0.11           1.00            1.0           1.00
# 13  Illinois           0.09           0.99            1.0           0.93
#
#     part_act_2018  part_act_2019  yoy_delta_part_sat  yoy_delta_part_act
# 5            0.30           0.27                0.89               -0.73
# 13           0.43           0.35                0.91               -0.58

# %% [markdown]
# #### Observations:
# - XY Scatter further illustrates a positive correlation between 2017 ACT and 2019 ACT participation rates
# - The two outlier's seen on this plot are represented by Coloraro and Illinois as seen in the dataframe directly above this cell.

# %%
#SAT particiption rates vs. total score 2017 
xy_scatter(['total_sat_2017','part_sat_2017'],['2017 SAT Total Score','2017 SAT Participation'])

# %%
#SAT particiption rates vs. total score 2018 
xy_scatter(['total_sat_2018','part_sat_2018'],['2018 SAT Total Score','2018 SAT Participation'])

# %% [markdown]
# #### Observations:
#
# - The highest SAT scores are negatively correlated with high SAT participation. This possibly indicates that in states where students are not mandated to but chose to write the SAT, they end up scoring higher given it is their choice to study and write the exam.

# %%
#ACT particiption rates vs. total score 2017 
xy_scatter(['composite_act_2017','part_act_2017'],['2017 ACT Composite Score','2017 ACT Participation'])

# %%
#ACT particiption rates vs. total score 2018
xy_scatter(['composite_act_2018','part_act_2018'],['2018 ACT Composite Score','2018 ACT Participation'])

# %% [markdown]
# #### Observations:
#
# - The highest ACT scores are negatively correlated with high ACT participation. This possibly indicates the same trend as mentioned for the SAT above.

# %%
#Time series of ACT and SAT average participation trend YoY
#Import DataFrame to create a new dataframe
from pandas import DataFrame

#Filter dataframe to only show participation columns
x = final.loc[:,['part_sat_2017','part_act_2017','part_sat_2018','part_act_2018','part_sat_2019','part_act_2019']]
#Calulcate the mean on the filtered dataframe
x = x.mean() 
#Create a list for each test type, the mean participation rate and the year of the test
list_sat = [['part_sat_2017',0.398039,'01/01/2017'],['part_sat_2018',0.457451,'01/01/2018'],['part_sat_2019',0.490588,'01/01/2019']]
list_act = [['part_act_2017',0.652549,'01/01/2017'],['part_act_2018',0.617255,'01/01/2018'],['part_act_2019',0.586667,'01/01/2019']]

#Transform lists into a dataframe
df_sat = pd.DataFrame(list_sat, columns =['test','mean','year'])
df_act = pd.DataFrame(list_act, columns =['test','mean','year'])

#Convert date string to year format
df_sat['year'] = pd.to_datetime(df_sat['year'])
df_act['year'] = pd.to_datetime(df_act['year'])

# Establish the size of the figure.
plt.figure(figsize=(16, 9))

# Create line plot of SAT and ACT mean over time
plt.plot(df_sat['year'],df_sat['mean'],label = 'SAT Participation')
plt.plot(df_act['year'],df_act['mean'],label = 'ACT Participation')
plt.legend(loc = 'upper right')

#Add titles and x,y labels
plt.title('\nSAT vs. ACT Participation from 2017 to 2019',fontsize=17).set_position([0.5,1.05])
plt.ylabel('Average participation rate', fontsize = 15)
plt.xlabel('\nTime', fontsize = 15);

# %%
participation.loc[(abs(participation['yoy_delta_part_sat']) > 0.2),['state','yoy_delta_part_sat']]

# Set size of figure: eight by five.
plt.figure(figsize=(10, 6))

#Create lists to make barchart
states = ['Colorado','Illinois','Rhode Island','West Virgina']
yoy_delta = [0.89,0.91,0.29,0.85]

# Create a bar chart.
plt.bar(states,yoy_delta)

# Add a title and show the plot.
plt.title("States with largest change in SAT participation between 2017 and 2019",fontsize=15)
plt.ylabel('Difference in participation b/w 2017 & 2019', fontsize = 13)
plt.xlabel('\nStates', fontsize = 13);

# %%
participation.loc[(abs(participation['yoy_delta_part_act']) > 0.2),['state','yoy_delta_part_act']]

# Set size of figure: eight by five.
plt.figure(figsize=(10, 6))

#Create lists to make barchart
states = ['Alaska','Colorado','Illinois','Ohio','South Carolina']
yoy_delta = [-0.27,-.073,-0.58,0.25,-0.22]

# Create a bar chart.
plt.bar(states,yoy_delta)

# Add a title and show the plot.
plt.title("States with largest change in ACT participation between 2017 and 2019",fontsize=15)
plt.ylabel('Difference in participation b/w 2017 & 2019', fontsize = 13)
plt.xlabel('\nStates', fontsize = 13);

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %%
#Not able to download tableau to my personal computer unfortunatley

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Two states that were of interest from exploring this dataset were Colorado and Ohio. I researched Colorado in order to confirm my hypothesis that they underweant a statewide transition from the ACT to the SAT and to gain a better understanding of the drivers of a state that has successfuly transitioned students from the ACT to SAT. Given Ohio has had a significant improvement in the ACT participation rate over the last three years (+25%) but has not managed to obtain an SAT participation rate greater than 20%, it is an interesting state to analyze as it has a lot of potential to gain from the successes of states like Colorado.
#
# Colorado came up in the dataset as a state that very quickly increase their SAT participation rates while simultaneously dropping their ACT rates to near 0. Given this is the first state that I wanted to understand better through external research.
#
# Here are the highlights illustrating why Colorado's participation rates on the SAT went from near 0% to nearly 100% in a matter of three years:
#
# - In 2015, state lawmakers voted that the Colorado Dpt. of Education must make competitive bids for college-entrance exams. Following this vote, the state decided to switch tests and replace the ACT with the SAT as the standard college entrance test for high school juniors to take
# - In spring 2017, 5000 (11%) Colorado high school juniors took the SAT for the very first time
# - As our data suggests, the trial period in 2017 was a success and in 2018, Colorado scored 100% participation on the SAT with the ACT falling to 30% participation.
# - This transition meant the SAT was being administered statewide at no cost
# - The college board provided free SAT study materials to everyone in state
#
# The primary driver for the high particiaption rate in Colorado is driven directly from changing state policies but a lot can be learnt from their success in transitioning from 100% ACT participation to 100% SAT participation in only 1 academic year. It is worth noting that Illinois exhibited the exact same pattern as Colorado (very quickly transitioning from high ACT participation rates to very high SAT rates). Upon further reserch, it is clear that Illinois underwent the same state-wide policy change from the ACT to the SAT as of 2017.
#
#
# Both of these states transiton from the ACT to the SAT comes in parralel to the College Board releasing their redesigned SAT in 2016. One of the primary goals of the overhaul was to align the SAT with the Common Core Standards (https://blog.prepscholar.com/what-is-the-common-core) making the test much more appealing as an assessment test than the older version.
#
# The reasons both states have cited for their successes are the following:
# - "They found that the College Board’s Practice SAT, given to 10th-graders, aligned better with the high school Colorado Academic Standards, a requirement of 2015 legislation" - Will Morton, director of assessment administration for the CDE -
# - "The College Board’s reporting system was also considered more useful to students, because it connects them to resources and activities to best help them succeed"- Will Morton, director of assessment administration for the CDE
# - "The College Board has done a good job redesigning both the PSAT and SAT to better measure what students are learning in high school and what they need to know to succeed in college"- Will Morton, director of assessment administration for the CDE
# - The decision to transition was made based on the mutual agreement that the SAT exam is:
#     - More relevant to the material they learned in high school
#     - Removes guesswork associated with timed questions
#     - Allowed 43% more time than the old ACT
#     - No science section
#     - Math section is simpler
#     - Simplified and more relevant words in the vocabulary section
# - "This SAT is frankly so much easier, so much closer to what students are seeing in their classes" - Sal Khan, Founder and President of Khan Academy
# - Khan Academy teamed with the College Board to provide free and personalized SAT study courses for Colorado students
# - Other test-prep companies are doing the same in advance of the administration of the SAT on April 11
# - Students can prep for test online, via Skype or in class at school
#
# In Ohio, passing the ACT or SAT is a requirement to graduate from high school. As of 2018, the state of Ohio decided to cover the cost for the ACT or SAT for all eligible high school juniors. This led to a greatly improved ACT participation rates (25% improvement) between 2017 and 2018. Over the same period the SAT has struggled to move above the 20% participation rate despite the updates/re-design to the SAT made in 2016.
#
# This discrepancy in participation between the exams can be explained due to the fact that districts select one exam (either the SAT or ACT) to offer for the state-sponsored administration test. The students are responsible to pay for the cost of any additional administrations of the exam. Given that about 95 percent of Ohio districts have chosen the ACT over the SAT, according to the state Dpt. of Education, the cost and burden of taking the SAT often falls to students electing to take the additional examination.
#
# Unfortunatley, the improvement in participation of the ACT was also accompanied by a significant decline in mean ACT test scores. The composite scores fell from 22.0 in 2017 to 20.3 in 2018 and 20.0 in 2019. This has raised questions about how well the ACT is aligned to the Ohio education standards.
#
# Given the context, Ohio is an excellent candidate for the College board to focus on targetting participation rate improvements. We can apply the successful learnings from Colorado's SAT transition and leverage the overhauled student-accessible SAT design to gain traction amonst school districts for their future decision making. In 2018, 127K students took the ACT in Ohio whereas only 22.8K (18%) took the SAT. There is a lot of potential for increases in SAT particiaption (~5.5x of possible growth)in Ohio as well as the state infrustructure & funding to support this growth.
#
# External Sources:
#
# [Colorado juniors SAT college exam](https://www.denverpost.com/2017/03/06/colorado-juniors-sat-college-exam/)
#
# [From CSAP to PARCC here's how colorado's standardized tests have changed and what's next](https://co.chalkbeat.org/2017/7/5/21100001/from-csap-to-parcc-here-s-how-colorado-s-standardized-tests-have-changed-and-what-s-next)
#
# [Prepscholar Blog Post](https://blog.prepscholar.com/which-states-require-the-sat#:~:text=These%20states%20include%20Alaska%2C%20Arkansas,it%20a%20requirement%20for%20graduation)
#
# [ACT-SAT Preference Infographic](https://www.collegeraptor.com/getting-in/articles/act-sat/preference-act-sat-state-infographic/)
#
# [Historically low ACT scores red flag for Ohio and our Country](https://www.daytondailynews.com/news/historically-low-act-scores-red-flag-for-our-country/djfx9Urp719WyEaMfykyxL/)
#
# [Ohio State Gov Education](http://education.ohio.gov/Topics/Ohio-s-Graduation-Requirements/College-and-Career-Readiness-Test)
#
# [Ohio State Gov Education](http://education.ohio.gov/Topics/Testing/ACT-SAT-FAQs#FAQ2842)
#
# [Ohio State Gov Education](https://education.ohio.gov/getattachment/Topics/Quality-School-Choice/Private-Schools/Forms-and-Program-Information-for-Nonpublic-School/Chartered-Nonpublic-Graduation-FAQ-1.pdf.aspx)
#
# [Ohio schools must now give ACT or SAT to all juniors](https://www.dispatch.com/news/20170228/ohio-schools-must-now-give-act-or-sat-to-all-juniors)
#
# [Program overview for ACT Ohio state funded testing](https://www.act.org/content/dam/act/unsecured/documents/pdfs/Program-Overview-for-ACT-Ohio-State-Funded-Testing.pdf)

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# The ACT and SAT participation distributions roughly mirror each other, with states geographically tending to prefer one test or the other. The ACT shows a large group of highly committed states (many states with participation rates of 100%) and a higher baseline participation nationwide. The SAT shows a larger group of states with 50-80% participation, as well as a smaller set of highly committed states. The ACT has histroically been the test of choice across the U.S. That said, the SAT revamped their test as of 2016 and since then has displayed an uptrend in their nationwide participation rates.
#
# There are strong regional and histroical affiliations associated with test preference in each state. Coastal states tend to favor the SAT, while Midwestern and Mountain states tend to favor the ACT.
#
# ACT and SAT scores are inversely correlated with their respective participation rates. This is most likely due to selection bias. Those who are electing to participate in states with no mandated requirement for that test are also taking on both the financial and time burden in order to take the test. This means that state particiaption will be low in these states but those that are particiapting will be higher achieving. In states wih very high participation, it likely means that the test is mandated by the state, includes the whole student population and therefore there is diluted quality of test scores.
#
# We can apply the successful learnings from Colorado's successful SAT transition and leverage the overhauled student-accessible SAT design to gain traction amonst Ohio school districts for their future decision making. In 2018, 127K students took the ACT in Ohio whereas only 22.8K (18%) took the SAT. There is a lot of potential for increases in SAT particiaption (~5.5x of possible growth) in Ohio as well as the state infrustructure & funding to support this growth.
#
# Moving onto the next phase of this analysis would require additional resources and data. In order to properly strategize our campaign in Ohio, it will be critical to get access to granular statewide data by school district in order to better understand local trends and ensure our approach aligns to their requirements & needs.

# %% [markdown]
# ## Bonus: Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:
# - part_sat_2017: This is not a normal distribution. Mean = , Std =
# - ebrw_sat_2017:
# - math_sat_2017:
# - total_sat_2017:
# - part_act_2017:
# - english_act_2017:
# - math_act_2017:
# - reading_act_2017:
# - science_act_2017:
# - composite_act_2017:
# - part_sat_2018:
# - ebrw_sat_2018:
# - math_sat_2018:
# - total_sat_2018:
# - part_act_2018:
# - composite_act_2018:

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: The data is not normally distributed

# %% [markdown]
# Does This Assumption Hold for:
#     - Math: The ACT math scores exhibit more of a normal distribution that the SAT math scores.That said, there is some skew to both sets of data. The SAT math scores have a more significant leftside skew than the ACT scores. It would be possible to make high level inferences at the national level based on this data but I would add a confidence internal/caveate.
#     - Reading: Same answer as above. ACT are more normally distributed than the SAT scores. It would be possible to make inferences based on this data with an added confidence interval and caveat.
#     - Participation Rates: Given the skew in the data to the rightside (ACT) and leftside (SAT) this assumption does hold true. It would be hard to accuratley make inferences and generalize based on this data at the national level.
#
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: See above

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: No it does not. This data is from 51 states across the country with various population sizes. The population sizes for each participation rate is not accounted for or weighted when rolling up the data at the national level. The level of aggregation of the data washed out most of the trends one would see when analyzing data at a more granular level. This data is too aggregated and general to make any real statsitical inferences.
#
# Also a single year of a data is generally not enough to perform any sort of real statisitcal analysis. 3 years of historical data is generally the minimum for this type of analysis.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: No it is not appropriate as these two scores are orders of magnitude off from eachother. Additioanlly there are many unknown differences between the two test sub sections that make direct comparison less useful. Some unknowns factors in section scoring include:
# - Length of math section in the test
# - Overall difficult of section compared with other sections of the test and other tests
# - Position of the math section in the test (Did students start or end with the math section?)
# - Different states specifically mandate different tests. Without knwoing the state by state demographic and educational factors influencing the scores at the aggregate level, it is difficult to make truly compare these tests

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:
